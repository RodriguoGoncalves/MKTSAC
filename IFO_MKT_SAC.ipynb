# %% [markdown]
# <a href="https://colab.research.google.com/github/RodriguoGoncalves/caseIfood/blob/main/IFO_MKT_SAC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img alt="Colaboratory logo" width="55%" src="https://github.com/RodriguoGoncalves/Sigmoidal_data_science/blob/main/banner2.png?raw=true">
#
#
# #### ***Modelo Preditivo - Campanha de Marketing***
# *by Rodrigo Gonçalves* ([Github](https://github.com/RodriguoGoncalves/Sigmoidal_data_science), [Linkedin](https://www.linkedin.com/in/rodrigo-gon%C3%A7alves-a22b6012a//), [Medium](https://medium.com/@rodriguogoncalves) )
#
# ###### Dt criação versão 1: ` 18/01/2022`
# ###### Observação 1: ` sabendo que o case de resolução trata de uma empresa fictícia, tomamos a liberdade de nomear esta empresa como Ifood mas já sabendo que toda a ánalise não se resume à realidade da empresa`
#
# ###### Observação 2: `O Nome do script é composto pelas 3 primeiras siglas da empresa, 3 siglas que representam o setor(MKT = Marketing) e as 3 siglas que representam a forma de captação da pesquisa(SAC = Serviço de Atendimento ao Cliente)`
# ---
# <center><img alt="Alvo_Inverso" width="15%" src="https://raw.githubusercontent.com/RodriguoGoncalves/caseIfood/cbdd602ea1245ed0a62678a4a24be45c15059d0e/1_IFOOD.png"></center>
#
# # ***Análise Exploratória de Dados Cooptados Via SAC***
#
#
# O  [Ifood](https://www.ifood.com.br/)  é considerado uma empresa bem estabelecida operando no setor de **varejo de alimentos**. Atualmente, há uma  estimativa  de **1.000.000(um milhão)** de consumidores atendidos por ano. Os adquirentes usufruem das 5 grandes categorias de produtos que são: **vinhos, carnes raras, frutas exóticas, peixe preparado e doces**. Tais produtos se subdividem em **ouro e regular**.
#
# Apesar da linha de fluxo saudável no *passado*, juntamente com a obtenção de receitas sólidas, a perspectiva projetada para os próximos 3 anos não são vingadoras. Desta forma, tem-se difundido as várias iniciativas estratégicas pela organização. Nesta análise, visando dar novos insights e economicidade para que  haja  à continuidade embasada das atividades iniciadas pelo setor de Marketing, vamos trazer o brilho quantitativo retornado pelos dados.

# %% [markdown]
# ## ***Obtenção dos Dados***
#
# Todos os dados usados aqui foram obtidos a partir do github em que foi disponibilizado o case. Neste [link](https://github.com/ifood/ifood-data-business-analyst-test), é possível importar o arquivo ml_project1_data.csv para um DataFrame, conforme consta na [imagem](https://raw.githubusercontent.com/RodriguoGoncalves/caseIfood/597685c5b3ede23fbf68db974dfc158353fa9a9b/Imagem_ml_projects_csv.PNG).
#
# Para esta análise exploratória inicial, será baixado apenas o seguinte arquivo:
#
# * `ml_project1_data.csv`
#
# Importante: O github está em constante evolução e, em determinado momento, pode ser que o [conjunto de dados](https://raw.githubusercontent.com/ifood/ifood-data-business-analyst-test/master/ml_project1_data.csv) exato utilizado nesse notebook não esteja mais disponível, o que quebraria nosso código.
#
# Pensando nisso, disponibilizamos [aqui](https://raw.githubusercontent.com/RodriguoGoncalves/caseIfood/main/ml_project1_data.csv) o conjunto que utilizamos, para que você sempre consiga utilizar esse material.
#
# Com isso em mente, vamos ao projeto.
# <center><img alt="Entregador" width="25%" src="https://github.com/RodriguoGoncalves/caseIfood/blob/main/2_Entregador.jpg?raw=true"></center>

# %% [markdown]
# ###***Instalações de Pacotes (Explicação)***
#
# * ***!pip install plotly==5.5.0*** >>  é uma biblioteca de plotagem interativa de código aberto que oferece suporte a mais de 40 tipos de gráficos exclusivos, cobrindo uma ampla variedade de casos de uso estatísticos, financeiros, geográficos, científicos e tridimensionais.
#
# * **!pip install -U scikit-learn** >>  é uma biblioteca de aprendizado de máquina de código aberto para a linguagem de programação Python.Ela inclui vários algoritmos de *classificação, regressão e agrupamento* incluindo máquinas de vetores de *suporte, florestas aleatórias, gradient boosting, k-means e DBSCAN*, e é projetada para interagir com as bibliotecas Python numéricas e científicas NumPy e SciPy.
#
# * ***!pip install numpy*** >> é uma poderosa biblioteca Python que é usada principalmente para realizar cálculos em Arrays Multidimensionais. O NumPy fornece um grande conjunto de funções e operações de biblioteca que ajudam os programadores a executar facilmente cálculos numéricos. Para aprofundamento, [clique aqui](https://medium.com/ensina-ai/entendendo-a-biblioteca-numpy-4858fde63355).
#
# * ***!pip install scipy*** >>  é o pacote básico da linguagem Python que implementa diversas técnicas úteis na computação científica. Utiliza como base o NumPy para lidar eficientemente com grandes quantidades de números, e implementa em linguagem C diversos algoritmos numéricos e simbólicos para o processamento matemático. Para aprofundamento, [clique aqui](http://pyscience-brasil.wikidot.com/module:scipy).

# %%
      #Instalações de Pacotes (Execução)

# !pip install plotly==5.5.0
# !pip install -U scikit-learn
# !pip install numpy 
# !pip install scipy
# !pip install qrcode
# Out:
# ...
#      |████████████████████████████████| 43 kB 1.3 MB/s
# ...
#   Created wheel for qrcode: filename=qrcode-7.3.1-py3-none-any.whl size=40402 sha256=7ac5770ed1de8f09e2d69a765e811f2a968ca51c9db926145eaa1137e159a59e
#   Stored in directory: /root/.cache/pip/wheels/93/d7/39/a4111be2cfb8e679938aa671a37888b6afb1f9e7d748e94492
# Successfully built qrcode
# ...

# %% [markdown]
# ###***Importações (Explicação)***
#
# * ***import pandas as pd*** >> é uma biblioteca de software criada para a linguagem Python para manipulação e análise de dados. Em particular, oferece estruturas e operações para manipular tabelas numéricas e séries temporais. Para aprofundamento, [clique aqui](https://medium.com/tech-grupozap/introdu%C3%A7%C3%A3o-a-biblioteca-pandas-89fa8ed4fa38).
#
# * ***import matplotlib.pyplot as plt*** >> O **Matplotlib** é uma biblioteca para a visualização de dados em Python. Ele apresenta uma API orientada a objetos que permite a criação de gráficos em 2D de uma forma simples e com poucos comandos. A ferramenta disponibiliza diversos tipos de gráficos, como em barra, em linha, em pizza, histogramas entre outras opções. O **PyPlot** é um módulo do matplotlib para criação de gráfico. Para aprofundamento, [clique aqui](https://king.host/blog/2018/03/visualizacao-de-dados-matplotlib/).
#
#
# * ***import seaborn as sns*** >> simplifica e abstrai algumas configurações de temas que seriam mais complexas do matplotlib, gerando gráficos mais atrativos com códigos mais limpos e mais simples. Para aprofundamento, [clique aqui](https://cienciadedadosuff.github.io/cursos/notebooks/caderno-3.html).
#
# * ***from plotly import graph_objects as go*** >> Os objetos plotly graph são uma interface de alto nível para plotly, que são fáceis de usar. Ele pode traçar vários tipos de gráficos e diagramas, como gráficos de dispersão, gráficos de linha, gráficos de barras, gráficos de caixa, histogramas, gráficos de pizza, etc.  Para aprofundamento, [clique aqui](https://acervolima.com/introducao-ao-plotly-python/).
#
# * ***import plotly.express as px*** >> é uma abstração de alto nível para Plotly API otimizada para funcionar perfeitamente com frames de dados. Para aprofundamento, [clique aqui](https://ichi.pro/pt/visualizacao-com-plotly-express-guia-completo-258792796523351) ou [neste link](https://plotly.com/python/plotly-express/) para acessar a biblioteca.
#
# * ***import json*** >>  é o formato mais usado para integração entre sistemas. Toda a linguagem de programação tem sua maneira de manipulá-lo. O Python tem uma biblioteca, chamada json. Para aprofundamento, [clique aqui](https://medium.com/@renatojlelis/trabalhando-com-json-no-python-1eb0f97c0c50).
#
# * **from urllib.request import urlopen** >> Há diversos módulos para acesso e processamento de protocolos da internet. Dois dos mais simples são *urllib.request* para efetuar download de dados a partir de URLs e *smtplib* para enviar mensagens de correio eletrônico. Para aprofundamento, [clique aqui](https://docs.python.org/pt-br/3/tutorial/stdlib.html).
#
# * ***numpy as np*** >>  é uma poderosa biblioteca Python que é usada principalmente para realizar cálculos em Arrays Multidimensionais. O NumPy fornece um grande conjunto de funções e operações de biblioteca que ajudam os programadores a executar facilmente cálculos numéricos. Para aprofundamento, [clique aqui](https://medium.com/ensina-ai/entendendo-a-biblioteca-numpy-4858fde63355).
#
#
# * ***from scipy import stats*** >> é o pacote básico da linguagem Python que implementa diversas técnicas úteis na computação científica. Utiliza como base o NumPy para lidar eficientemente com grandes quantidades de números, e implementa em linguagem C diversos algoritmos numéricos e simbólicos para o processamento matemático. Para aprofundamento, [clique aqui](http://pyscience-brasil.wikidot.com/module:scipy).
#
#
# * ***statsmodels.api as sm*** >> é um módulo Python que fornece classes e funções para a estimativa de muitos modelos estatísticos diferentes, bem como para a realização de testes estatísticos e exploração de dados estatísticos. Uma extensa lista de estatísticas de resultados está disponível para cada estimador. Os resultados são testados em relação aos pacotes estatísticos existentes para garantir que estejam corretos. O pacote é lançado sob a licença BSD modificada (3 cláusulas) de código aberto. Para aprofundamento, [clique aqui](https://www.statsmodels.org/stable/index.html).
#
#
#
# * ***from datetime import datetime*** >> Uma combinação de uma data e uma hora. Atributos: `ano`, `mês`, `dia`, `hora`, `minuto`, `segundo`, `microsegundo`, e `tzinfo`. Para aprofundamento, [clique aqui](https://docs.python.org/pt-br/3/library/datetime.html). Aqui, podemos citar  [Tipos no módulo datetime](https://github.com/RodriguoGoncalves/caseIfood/blob/main/4_MOD_DATE.png?raw=true), [Conversão entre string e datetime especificando os formatos conforme com a ISO C89](https://github.com/RodriguoGoncalves/caseIfood/blob/main/5_FORM_DATE.png?raw=true),[Formatação de data específica de localidades](https://github.com/RodriguoGoncalves/caseIfood/blob/main/6_LOCAL_DATE.png?raw=true) e o [Fatiamento de Strings "Slicing"](https://www.youtube.com/watch?v=kw88FTqG8Wo). Link extra sobre fatiamento: [clique aqui](https://computeel.org/LOM3260/material/tema2/05-slicing-indexing.html).<p>
#
#
# * ***from sklearn.cluster import KMeans*** >> é um algoritmo de clusterização (ou agrupamento) disponível na biblioteca Scikit-Learn.
# É um algoritmo de aprendizado não supervisionado (ou seja, que não precisa de inputs de confirmação externos) que avalia e clusteriza os dados de acordo com suas características. Para aprofundamento, [clique aqui](https://medium.com/programadores-ajudando-programadores/k-means-o-que-%C3%A9-como-funciona-aplica%C3%A7%C3%B5es-e-exemplo-em-python-6021df6e2572#:~:text=K%2DMeans%20%C3%A9%20um%20algoritmo,lojas%2Fcentro%20logistico).
#
#
#
# * ***from sklearn.ensemble import IsolationForest*** >>  é um algoritmo brilhante para detecção de anomalias criado em 2009 ( aqui está o artigo original). Desde então, tornou-se muito popular: também é implementado no Scikit-learn (consulte a documentação ). Para aprofundamento, [clique aqui](https://ichi.pro/pt/isolation-forest-o-algoritmo-de-deteccao-de-anomalias-que-qualquer-cientista-de-dados-deve-saber-29246079560749).
#
#
# * ***import os*** >> Ele é muito útil quando você precisar mexer no sistema de arquivos. Para aprofundamento, [clique aqui](http://devfuria.com.br/python/os/).
#
# * ***from sklearn.linear_model import LinearRegression*** >>  é definida como uma equação que visa estimar a condicional (valor esperado) de uma variável y, com base nos dados e valores de algumas outras variáveis x. A regressão, em geral, busca tratar de um valor que não se é possível consegue estimar inicialmente.   Uma regressão só é chamada “linear” quando se considera que a relação da resposta às variáveis é tratada como uma função linear (Ax+b). Aqueles modelos de regressão que não podem ser traduzidos em uma função linear dos parâmetros são denominados não-lineares.   Esse tipo de regressão é uma das primeiras formas de análise regressiva a ser estudada, e também é usada extensamente em aplicações práticas. Isso só acontece porque modelos que dependem de uma forma linear de seus parâmetros desconhecidos, são mais facilmente ajustados que os modelos não-lineares, além disso, as propriedades estatísticas dos estimadores resultantes são fáceis de determinar.    Para aprofundamento, [clique aqui](https://www.computersciencemaster.com.br/como-funciona-a-regressao-linear-simples/).
#
# * ***from sklearn.decomposition import PCA*** >>
#   * *Quando existem muitos atributos de entrada, é difícil visualizar os dados. Existe um termo muito famoso 'Maldição da dimensionalidade no domínio do aprendizado de máquina.*
#   * *Basicamente, refere-se ao fato de que um número maior de atributos em um conjunto de dados afeta negativamente a precisão e o tempo de treinamento do modelo de aprendizado de máquina.*
#   * *A Análise de Componentes Principais (PCA) é uma maneira de resolver esse problema e é usada para melhor visualização de dados e aumento da precisão.*
#  Para aprofundamento, [clique aqui](https://acervolima.com/implementando-pca-em-python-com-scikit-learn/)
#
# * ***from sklearn.preprocessing import StandardScaler*** >> Padronize recursos removendo a média e dimensionando para a variação da unidade. Para aprofundamento, [clique aqui](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html)
#
# * ***from collections import Counter*** >> Este módulo implementa tipos de dados de contêineres especializados que fornecem alternativas aos contêineres embutidos do Python, dict, list, set e tuple. Para aprofundamento, [clique aqui](https://docs.python.org/pt-br/3/library/collections.html)
#
#
# * ***from sklearn.preprocessing import KBinsDiscretizer*** >> A transformação quantílica  agrupa os registros de dados de cada variável em k grupos. Para aprofundamento, [clique aqui](https://www.journaldev.com/54363/data-discretization-python-sklearn)
#
#
#
# * ***from sklearn.model_selection import train_test_split*** >> Divida matrizes ou matrizes em subconjuntos aleatórios de treinamento e teste. Para aprofundamento, [clique aqui](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)
#
#
#
# * ***from sklearn.cluster import AgglomerativeClustering*** >> objeto realiza um agrupamento hierárquico usando uma abordagem de baixo para cima: cada observação começa em seu próprio cluster e os clusters são sucessivamente mesclados. Os critérios de vinculação determinam a métrica usada para a estratégia de mesclagem.  Para aprofundamento, [clique aqui](https://scikit-learn.org/stable/modules/clustering.html#hierarchical-clustering)
#
#
#
# * ***from sklearn.tree import DecisionTreeClassifier*** >> é  um método de aprendizado supervisionado não paramétrico usado para classificação e regressão. O objetivo é criar um modelo que preveja o valor de uma variável de destino aprendendo regras de decisão simples inferidas a partir dos recursos de dados. Uma árvore pode ser vista como uma aproximação constante por partes. Para aprofundamento, [clique aqui](https://scikit-learn.org/stable/modules/tree.html#tree)
#
#
# * ***from xgboost import XGBClassifier*** >> é uma implementação de árvores de decisão impulsionadas por gradiente projetadas para velocidade e desempenho que é o aprendizado de máquina competitivo dominante. Para aprofundamento, [clique aqui](https://machinelearningmastery.com/develop-first-xgboost-model-python-scikit-learn/)
#
#
# * ***import openpyxl*** >> é uma biblioteca Python para leitura e gravação de arquivos Excel (com extensão xlsx / xlsm / xltx / xltm). O módulo openpyxl permite que o programa Python leia e modifique arquivos Excel. Para aprofundamento, [clique aqui](https://acervolima.com/lendo-um-arquivo-excel-usando-o-modulo-python-openpyxl/#:~:text=Openpyxl%20%C3%A9%20uma%20biblioteca%20Python,leia%20e%20modifique%20arquivos%20Excel.&text=Usando%20o%20m%C3%B3dulo%20Openpyxl%2C%20essas,forma%20muito%20eficiente%20e%20f%C3%A1cil.)
#
# * ***from sklearn.preprocessing import MinMaxScaler*** >> é uma técnica de pré-processamento que coloca os dados na mesma escala.Transforma as features ao deixá-las na mesma escala em um determinado range. Este estimador escala e traduz cada feature individualmente de forma que esta estará em um determinado intervalo no conjunto de treino, por exemplo, entre zero e um. Para aprofundamento, [clique aqui](https://sigmoidal.ai/guia-basico-de-pre-processamento-de-dados/#:~:text=MinMaxScaler%20do%20Sklearn%20%C3%A9%20uma,escala%20em%20um%20determinado%20range.)
#
#
# * ***import os*** >> Um dos benefícios do clustering hierárquico é que você não precisa saber antecipadamente o número de clusters k em seus dados. Infelizmente, não parece haver muita documentação sobre como realmente usar o agrupamento hierárquico do scipy para tomar uma decisão informada e, em seguida, recuperar os agrupamentos. Para aprofundamento, [clique aqui](https://joernhees.de/blog/2015/08/26/scipy-hierarchical-clustering-and-dendrogram-tutorial/)
#
#
# * ***import os*** >> Ele é muito útil quando você precisar mexer no sistema de arquivos. Para aprofundamento, [clique aqui](http://devfuria.com.br/python/os/)
#
#
# * ***%matplotlib inline*** >> Com esse back-end, a saída dos comandos de plotagem é exibida embutida nos front-ends, como o bloco de notas Jupyter, diretamente abaixo da célula de código que a produziu. Os gráficos resultantes também serão armazenados no documento de caderno. Para aprofundamento, [clique aqui](https://ipython.readthedocs.io/en/stable/interactive/plotting.html).

# %%
                    #Importações (Execução)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from plotly import graph_objects as go
import plotly.express as px
import json
from urllib.request import urlopen
import numpy as np
from scipy import stats
import statsmodels.api as sm
from datetime import datetime
from sklearn.cluster import KMeans
from sklearn.ensemble import IsolationForest
import os
from sklearn.linear_model import LinearRegression
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from collections import Counter
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.model_selection import train_test_split
from sklearn.cluster import AgglomerativeClustering
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
import openpyxl
from sklearn.preprocessing import MinMaxScaler
from scipy.cluster.hierarchy import dendrogram, linkage
import qrcode




# %matplotlib inline
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# importar o arquivo ml_project1_data.csv para um DataFrame
df = pd.read_csv("https://raw.githubusercontent.com/RodriguoGoncalves/caseIfood/main/ml_project1_data.csv")

# %% [markdown]
# ## ***Análise dos Dados***
#
#
# *A finalidade desta etapa é mostrar a estrutura dos dados e dar uma visão geral das variáveis que iremos trabalhar.*

# %% [markdown]
# **Dicionário das variáveis**
#
# * `id` - número de id gerado para identificar o cliente.
# * `Year_Birth` - para identificar se o ANO DE NASCIMENTO influi em algum fator da análise.
# * `Education` - para identificar se a EDUCAÇÃO ESCOLAR  influi em algum fator da análise.
# * `Marital_Status` - para identificar se o ESTADO CIVIL influi em algum fator da análise.
# * `Income` -  para identificar se a RENDA influi em algum fator da análise.
# * `Kidhome` - para identificar se há e a quantidade de crianças na casa.
# * `Teenhome` -para identificar se há e a quantidade de adolescentes na casa.
# * `Dt_Customer` - quando começou a relação entre o cliente e a empresa.
# * `Recency` - demonstra o quanto estamos presentes na mente dos nossos clientes. O agrupamento dos clientes é feito por outro critério: Há quanto tempo nossos clientes realizaram a última compra na loja.Ela deve considerar um período amostral adequado e possuir faixas apropriadas para aquele tipo de negócio: Nem pequenas demais que atrapalhem a visualização gráfica e nem amplas demais que não apresentem as variações ocorridas.
# * `MntWines` - Unidades monetárias gastas em vinho.
# * `MntFruits` - Unidades monetárias gastas em frutas.
# * `MntMeatProducts` - Unidades monetárias gastas em produtos relacionados a carnes.
# * `MntFishProducts` - Unidades monetárias gastas em produtos relacionados a peixes.
# * `MntSweetProducts` - Unidades monetárias gastas em produtos relacionados a doces.
# * `MntGoldProds` - Unidades monetárias gastas em produtos relacionados a categoria ouro.
# * `NumDealsPurchases` - Número  de compras por ofertas.
# * `NumWebPurchases` - Número  de compras pela web.
# * `NumCatalogPurchases` - Número  de compras por catálogo.
# * `NumStorePurchases` - Número  de compras pela loja.
# * `NumWebVisitsMonth` - Número de visitantes na web por Mes.
# * `AcceptedCmp3` - Aceitação da campanha 3.
# * `AcceptedCmp4` - Aceitação da campanha 4.
# * `AcceptedCmp5` - Aceitação da campanha 5.
# * `AcceptedCmp1` - Aceitação da campanha 1.
# * `AcceptedCmp2` - Aceitação da campanha 2.
# * `Complain` - Reclamação.
# * `Z_CostContact` - pCusto dos contatos.
# * `Z_Revenue` - quantidade mínima de noites para reservar.
# * `Response` - Respostas.
#
# Vamos verificar os traços do nosso *dataset (conjunto de dados)*, analisando as 7 primeiras entradas, de maneira prévia aos questionamentos que começaremos a fazer.

# %%
# mostrar as 7 primeiras entradas
df.head(7)
# Out:
#      ID  Year_Birth   Education  ... Z_CostContact  Z_Revenue  Response
# 0  5524        1957  Graduation  ...             3         11         1
# 1  2174        1954  Graduation  ...             3         11         0
# 2  4141        1965  Graduation  ...             3         11         0
# 3  6182        1984  Graduation  ...             3         11         0
# 4  5324        1981         PhD  ...             3         11         0
# 5  7446        1967      Master  ...             3         11         0
# 6   965        1971  Graduation  ...             3         11         0
#
# [7 rows x 29 columns]

# %% [markdown]
# ### ***Quantos atributos (variáveis) e quantas entradas o conjunto de dados possui? Quais os tipos das variáveis?***

# %%
# identificar a dimensão do dataset
print("Entradas:\t {}".format(df.shape[0]))
print("Variáveis:\t {}\n".format(df.shape[1]))

# identificar tipo das variáveis
df.dtypes
# Out:
# Entradas:	 2240
# Variáveis:	 29
# ID                       int64
# Year_Birth               int64
# Education               object
# Marital_Status          object
# Income                 float64
# Kidhome                  int64
# Teenhome                 int64
# Dt_Customer             object
# Recency                  int64
# MntWines                 int64
# MntFruits                int64
# MntMeatProducts          int64
# MntFishProducts          int64
# MntSweetProducts         int64
# MntGoldProds             int64
# NumDealsPurchases        int64
# NumWebPurchases          int64
# NumCatalogPurchases      int64
# NumStorePurchases        int64
# NumWebVisitsMonth        int64
# AcceptedCmp3             int64
# AcceptedCmp4             int64
# AcceptedCmp5             int64
# AcceptedCmp1             int64
# AcceptedCmp2             int64
# Complain                 int64
# Z_CostContact            int64
# Z_Revenue                int64
# Response                 int64
# ...

# %% [markdown]
# ### **Qual a porcentagem de valores ausentes no *dataset*?**
# *Os valores ausentes dizem muito sobre a qualidade do dataset. Visando apresentar um dataset de qualidade, irei verificar se tem valores ausentes e decidir a partir desses se devo retirá-los ou não.*

# %%
# Ordenando em ordem decrescente as variáveis por seus valores ausentes
(df.isnull().sum() / df.shape[0]).sort_values(ascending=False) * 100
# Out:
# Income                 1.071429
# Response               0.000000
# MntSweetProducts       0.000000
# Year_Birth             0.000000
# Education              0.000000
# Marital_Status         0.000000
# Kidhome                0.000000
# Teenhome               0.000000
# Dt_Customer            0.000000
# Recency                0.000000
# MntWines               0.000000
# MntFruits              0.000000
# MntMeatProducts        0.000000
# MntFishProducts        0.000000
# MntGoldProds           0.000000
# Z_Revenue              0.000000
# NumDealsPurchases      0.000000
# NumWebPurchases        0.000000
# NumCatalogPurchases    0.000000
# NumStorePurchases      0.000000
# NumWebVisitsMonth      0.000000
# AcceptedCmp3           0.000000
# AcceptedCmp4           0.000000
# AcceptedCmp5           0.000000
# AcceptedCmp1           0.000000
# AcceptedCmp2           0.000000
# Complain               0.000000
# Z_CostContact          0.000000
# ID                     0.000000
# ...

# %%
def tb_val_ausentes(df):
        # Total de valores ausentes
        aus_val = df.isnull().sum()
        
        # Porcentagem de valores ausentes
        aus_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Faça uma tabela com os resultados
        aus_val_tb = pd.concat([aus_val,aus_val_percent], axis=1)
        
        # Faça uma tabela com os resultados
        aus_val_tb_ren_columns = aus_val_tb.rename(
        columns = {0 : 'Valores ausentes', 1 : '% de Valores Totais'})
        
        # Classifique a tabela por porcentagem de falta decrescente
        aus_val_tb_ren_columns = aus_val_tb_ren_columns[
            aus_val_tb_ren_columns.iloc[:,1] != 0].sort_values(
        '% de Valores Totais', ascending=False).round(1)
        
        # Imprima algumas informações resumidas
        print ("o dataframe selecionado tem " + str(df.shape[1]) + " colunas.\n"      
            "Há " + str(aus_val_tb_ren_columns.shape[0]) +
              " colunas com valores faltantes.")
        
        # Retorne o dataframe com informações ausentes
        return aus_val_tb_ren_columns
    
data_missing = tb_val_ausentes(df)
data_missing
# Out:
# o dataframe selecionado tem 29 colunas.
# Há 1 colunas com valores faltantes.
#         Valores ausentes  % de Valores Totais
# Income                24                  1.1

# %%
# mostrar visualmente valores faltantes
plt.figure(figsize=(5,3))
ax = sns.heatmap(df.isnull(), yticklabels=False, cmap='Oranges_r', cbar=False)
ax.set_title('Distribuição de valores faltantes no Dataset.', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Distribuição de valores faltantes no Dataset.')

# %% [markdown]
# *A coluna `income` (com 01.1% de valores nulos), contém dados que serão relevantes para nossa análise. Sendo assim, iremos analisá-lo com mais à frente.*
#
# ***consulta de cores para variar noplt.figure:*** https://abre.ai/cores-plt-figure

# %% [markdown]
# ### **Q3. Qual o tipo de distribuição das variáveis?**

# %% [markdown]
# *Este é um primeiro passo importante para descobrirmos se há algum outlier presente. Isto é, valores que fogem muito da distribuição (muito baixos ou muito altos).*

# %%
# Plotando o histograma das variáveis numéricas
histo = df.hist(bins=12, figsize=(22,15), grid=False, color= '#ff4d00',ec = "w");

# %% [markdown]
#  Verificando os histogramas, conseguimos ver claramente que temos outliers presentes. Para tratá-los vamos seguir os seguintes passos:
#
# * *Definir o Q1 e Q3 para as variáveis que serão limpas.*
# * *Calcular o IQR para as variáveis.*
# * *Definir o limite superior e inferior para cortar os outliers.*
# * *Remover os outliers.*

# %%
import qrcode
qr = qrcode.QRCode(
    version=1,
    error_correction=qrcode.constants.ERROR_CORRECT_L,
    box_size=4,
    border=4,
)
qr.add_data("https://github.com/lincolnloop/python-qrcode")
qr.make(fit=True)

img = qr.make_image(fill_color="black", back_color="white")

img
# Out:
# ---------------------------------------------------------------------------
# DataOverflowError                         Traceback (most recent call last)
# <ipython-input-59-a181d084a4c6> in <module>()
#       7 )
#       8 qr.add_data("data:image/png;base64,......
# ----> 9 qr.make(fit=True)
#      10
#      11 img = qr.make_image(fill_color="black", back_color="white")
#
# /usr/local/lib/python3.7/dist-packages/qrcode/main.py in make(self, fit)
#     101         """
#     102         if fit or (self.version is None):
# --> 103             self.best_fit(start=self.version)
#     104         if self.mask_pattern is None:
#     105             self.makeImpl(False, self.best_mask_pattern())
#
# /usr/local/lib/python3.7/dist-packages/qrcode/main.py in best_fit(self, start)
#     178                                    needed_bits, start)
#     179         if self.version == 41:
# --> 180             raise exceptions.DataOverflowError()
#     181
# ...

# %% [markdown]
# ## **Limpando Outliers**
#
#  *Para tratar dos outliers desse conjunto de dados, iremos analisar a distribuição estatística, plotar boxplots e calcular os limites utilizando a regra do IQR Score.*

# %%
# Pedindo ao Pandas uma visão mais descritiva dos nossos Dados 
df.describe().round(1)
# Out:
#             ID  Year_Birth    Income  ...  Z_CostContact  Z_Revenue  Response
# count   2240.0      2240.0    2216.0  ...         2240.0     2240.0    2240.0
# mean    5592.2      1968.8   52247.3  ...            3.0       11.0       0.1
# std     3246.7        12.0   25173.1  ...            0.0        0.0       0.4
# min        0.0      1893.0    1730.0  ...            3.0       11.0       0.0
# 25%     2828.2      1959.0   35303.0  ...            3.0       11.0       0.0
# 50%     5458.5      1970.0   51381.5  ...            3.0       11.0       0.0
# 75%     8427.8      1977.0   68522.0  ...            3.0       11.0       0.0
# max    11191.0      1996.0  666666.0  ...            3.0       11.0       1.0
#
# [8 rows x 26 columns]

# %% [markdown]
#  Aqui, algumas coisas já chamam a nossa atenção, como por exemplo:
#
# * A variável `Year_Birth` tem o ano mínimo referente ao de 1893 🧛🏽‍♂️.
# * Atualmente,  a pessoa [mais velha do mundo](https://www.cnnbrasil.com.br/internacional/pessoa-mais-velha-do-mundo-japonesa-kane-tanaka-completa-119-anos/#:~:text=Pessoa%20mais%20velha%20do%20mundo%2C%20japonesa%20Kane%20Tanaka%20completa%20119%20anos,-Exerc%C3%ADcios%20de%20matem%C3%A1tica) nasceu em 1903 (119 anos). Sendo assim, podemos inferir a presença de outliers na variável `Year_Birth`.
# * A variável `income` tem como seu máximo o valor 666.666.0, sendo que o Q3 está em 68.522.0. Sendo assim, podemos inferir a presença de outliers na variável `income`.
# * As variáveis `NumDealsPurchases`, `NumWebPurchases`, `NumCatalogPurchases`, `	NumStorePurchases` e  `Recency`também podem conter outliers, mas não vamos nos preocupar com elas agora.
# ---------

# %% [markdown]
# ### **Boxplot da variável** `Income`

# %%
q1_Income = df.Income.quantile(.25)
q3_Income = df.Income.quantile(.75)
IQR_Income = q3_Income - q1_Income
print('IQR da variável Income: ', IQR_Income)

sup_Income = q3_Income + 1.5 * IQR_Income
inf_Income = q1_Income - 1.5 * IQR_Income

print('Limite superior de Income: ', sup_Income)
print('Limite inferior de Income:: ', inf_Income)
# Out:
# IQR da variável Income:  33219.0
# Limite superior de Income:  118350.5
# Limite inferior de Income::  -14525.5

# %%
fig, ax = plt.subplots(figsize=(15,3))
df.Income.plot(kind='box', vert=False);
ax.set_title('Dataset Original - Income')
plt.show()
print("O dataset possui {} colunas".format(df.shape[0]))
print("{} Entradas acima de 118216.12".format(len(df[df.Income > 118216.125])))
print("Representam {:.2f}% do dataset".format((len(df[df.Income > 118216.125]) / df.shape[0])*100))
# Out:
# O dataset possui 2240 colunas
# 8 Entradas acima de 118216.12
# Representam 0.36% do dataset

# %% [markdown]
# ### **Boxplot da variável** `Year_Birth`

# %%
q1_Year_Birth = df.Year_Birth.quantile(.25)
q3_Year_Birth = df.Year_Birth.quantile(.75)
IQR_Year_Birth = q3_Year_Birth - q1_Year_Birth
print('IQR da variável Year_Birth: ', IQR_Year_Birth)

sup_Year_Birth = q3_Year_Birth + 1.5 * IQR_Year_Birth
inf_Year_Birth = q1_Year_Birth - 1.5 * IQR_Year_Birth

print('Limite superior de Year_Birth: ', sup_Year_Birth)
print('Limite inferior de Year_Birth:: ', inf_Year_Birth)
# Out:
# IQR da variável Year_Birth:  18.0
# Limite superior de Year_Birth:  2004.0
# Limite inferior de Year_Birth::  1932.0

# %%
fig, ax = plt.subplots(figsize=(15,3))
df.Year_Birth.plot(kind='box', vert=False);
ax.set_title('Dataset Original - Year_Birth')
plt.show()
print("O dataset possui {} colunas".format(df.shape[0]))
print("{} Entradas acima de 1932.0".format(len(df[df.Year_Birth < 1932.0])))
print("Representam {:.2f}% do dataset".format((len(df[df.Year_Birth < 1932.0]) / df.shape[0])*100))
# Out:
# O dataset possui 2240 colunas
# 3 Entradas acima de 1932.0
# Representam 0.13% do dataset

# %% [markdown]
# ### **Boxplot da variável** `Recency`

# %%
q1_Recency = df.Recency.quantile(.25)
q3_Recency = df.Recency.quantile(.75)
IQR_Recency = q3_Recency - q1_Recency
print('IQR da variável Recency: ', IQR_Recency)

sup_Recency = q3_Recency + 1.5 * IQR_Recency
inf_Recency = q1_Recency - 1.5 * IQR_Recency

print('Limite superior de Recency: ', sup_Recency)
print('Limite inferior de Recency:: ', inf_Recency)
# Out:
# IQR da variável Recency:  50.0
# Limite superior de Recency:  149.0
# Limite inferior de Recency::  -51.0

# %%
fig, ax = plt.subplots(figsize=(15,3))
df.Recency.plot(kind='box', vert=False);
ax.set_title('Dataset Original - Recency')
plt.show()
print("O dataset possui {} colunas".format(df.shape[0]))
print("{} Entradas acima de 149.0".format(len(df[df.Recency > 149.0])))
print("Representam {:.2f}% do dataset".format((len(df[df.Recency > 149.0]) / df.shape[0])*100))
# Out:
# O dataset possui 2240 colunas
# 0 Entradas acima de 149.0
# Representam 0.00% do dataset

# %% [markdown]
# ### **Boxplot da variável** `NumDealsPurchases`

# %%
q1_NumDealsPurchases = df.NumDealsPurchases.quantile(.25)
q3_NumDealsPurchases = df.NumDealsPurchases.quantile(.75)
IQR_NumDealsPurchases = q3_NumDealsPurchases - q1_NumDealsPurchases
print('IQR da variável NumDealsPurchases: ', IQR_NumDealsPurchases)

sup_NumDealsPurchases = q3_NumDealsPurchases + 1.5 * IQR_NumDealsPurchases
inf_NumDealsPurchases = q1_NumDealsPurchases - 1.5 * IQR_NumDealsPurchases

print('Limite superior de NumDealsPurchases: ', sup_NumDealsPurchases)
print('Limite inferior de NumDealsPurchases:: ', inf_NumDealsPurchases)
# Out:
# IQR da variável NumDealsPurchases:  2.0
# Limite superior de NumDealsPurchases:  6.0
# Limite inferior de NumDealsPurchases::  -2.0

# %%
fig, ax = plt.subplots(figsize=(15,3))
df.NumDealsPurchases.plot(kind='box', vert=False);
ax.set_title('Dataset Original - NumDealsPurchases')
plt.show()
print("O dataset possui {} colunas".format(df.shape[0]))
print("{} Entradas acima de 6.0".format(len(df[df.NumDealsPurchases > 6.0])))
print("Representam {:.2f}% do dataset".format((len(df[df.NumDealsPurchases > 6.0]) / df.shape[0])*100))
# Out:
# O dataset possui 2240 colunas
# 86 Entradas acima de 6.0
# Representam 3.84% do dataset

# %% [markdown]
# ### **Boxplot da variável** `NumWebPurchases`

# %%
q1_NumWebPurchases = df.NumWebPurchases.quantile(.25)
q3_NumWebPurchases = df.NumWebPurchases.quantile(.75)
IQR_NumWebPurchases = q3_NumWebPurchases - q1_NumWebPurchases
print('IQR da variável NumWebPurchases: ', IQR_NumWebPurchases)

sup_NumWebPurchases = q3_NumWebPurchases + 1.5 * IQR_NumWebPurchases
inf_NumWebPurchases = q1_NumWebPurchases - 1.5 * IQR_NumWebPurchases

print('Limite superior de NumWebPurchases: ', sup_NumWebPurchases)
print('Limite inferior de NumWebPurchases:: ', inf_NumWebPurchases)
# Out:
# IQR da variável NumWebPurchases:  4.0
# Limite superior de NumWebPurchases:  12.0
# Limite inferior de NumWebPurchases::  -4.0

# %%
fig, ax = plt.subplots(figsize=(15,3))
df.NumWebPurchases.plot(kind='box', vert=False);
ax.set_title('Dataset Original - NumWebPurchases')
plt.show()
print("O dataset possui {} colunas".format(df.shape[0]))
print("{} Entradas acima de 12.0".format(len(df[df.NumWebPurchases > 12.0])))
print("Representam {:.2f}% do dataset".format((len(df[df.NumWebPurchases > 12.0]) / df.shape[0])*100))
# Out:
# O dataset possui 2240 colunas
# 4 Entradas acima de 12.0
# Representam 0.18% do dataset

# %% [markdown]
# ### **Boxplot da variável** `NumCatalogPurchases`

# %%
q1_NumCatalogPurchases = df.NumCatalogPurchases.quantile(.25)
q3_NumCatalogPurchases = df.NumCatalogPurchases.quantile(.75)
IQR_NumCatalogPurchases = q3_NumCatalogPurchases - q1_NumCatalogPurchases
print('IQR da variável NumCatalogPurchases: ', IQR_NumCatalogPurchases)

sup_NumCatalogPurchases = q3_NumCatalogPurchases + 1.5 * IQR_NumCatalogPurchases
inf_NumCatalogPurchases = q1_NumCatalogPurchases - 1.5 * IQR_NumCatalogPurchases

print('Limite superior de NumCatalogPurchases: ', sup_NumCatalogPurchases)
print('Limite inferior de NumCatalogPurchases:: ', inf_NumCatalogPurchases)
# Out:
# IQR da variável NumCatalogPurchases:  4.0
# Limite superior de NumCatalogPurchases:  10.0
# Limite inferior de NumCatalogPurchases::  -6.0

# %%
fig, ax = plt.subplots(figsize=(15,3))
df.NumCatalogPurchases.plot(kind='box', vert=False);
ax.set_title('Dataset Original - NumCatalogPurchases')
plt.show()
print("O dataset possui {} colunas".format(df.shape[0]))
print("{} Entradas acima de 10.0".format(len(df[df.NumCatalogPurchases > 10.0])))
print("Representam {:.2f}% do dataset".format((len(df[df.NumCatalogPurchases > 10.0]) / df.shape[0])*100))
# Out:
# O dataset possui 2240 colunas
# 23 Entradas acima de 10.0
# Representam 1.03% do dataset

# %% [markdown]
# ### **Boxplot da variável** `NumStorePurchases`

# %%
q1_NumStorePurchases = df.NumStorePurchases.quantile(.25)
q3_NumStorePurchases = df.NumStorePurchases.quantile(.75)
IQR_NumStorePurchases = q3_NumStorePurchases - q1_NumStorePurchases
print('IQR da variável NumStorePurchases: ', IQR_NumStorePurchases)

sup_NumStorePurchases = q3_NumStorePurchases + 1.5 * IQR_NumStorePurchases
inf_NumStorePurchases = q1_NumStorePurchases - 1.5 * IQR_NumStorePurchases

print('Limite superior de NumStorePurchases: ', sup_NumStorePurchases)
print('Limite inferior de NumStorePurchases:: ', inf_NumStorePurchases)
# Out:
# IQR da variável NumStorePurchases:  5.0
# Limite superior de NumStorePurchases:  15.5
# Limite inferior de NumStorePurchases::  -4.5

# %%
fig, ax = plt.subplots(figsize=(15,3))
df.NumStorePurchases.plot(kind='box', vert=False);
ax.set_title('Dataset Original - NumStorePurchases')
plt.show()
print("O dataset possui {} colunas".format(df.shape[0]))
print("{} Entradas acima de 10.0".format(len(df[df.NumStorePurchases > 10.0])))
print("Representam {:.2f}% do dataset".format((len(df[df.NumStorePurchases > 10.0]) / df.shape[0])*100))
# Out:
# O dataset possui 2240 colunas
# 269 Entradas acima de 10.0
# Representam 12.01% do dataset

# %%
# Definindo o novo dataset sem outliers
df_clean = df.copy()

df_clean.drop(df_clean[df_clean.Income > 118350.5].index, axis=0, inplace=True)
df_clean.drop(df_clean[df_clean.Income == 0.0].index, axis=0, inplace=True)
df_clean.drop(df_clean[df_clean.Year_Birth > 2004.0].index, axis=0, inplace=True)
df_clean.drop(df_clean[df_clean.NumDealsPurchases > 6.0].index, axis=0, inplace=True)
df_clean.drop(df_clean[df_clean.NumWebPurchases > 12.0].index, axis=0, inplace=True)
df_clean.drop(df_clean[df_clean.NumCatalogPurchases > 10.0].index, axis=0, inplace=True)
df_clean.drop(df_clean[df_clean.NumStorePurchases > 15.5].index, axis=0, inplace=True)
df_clean.drop(df_clean[df_clean.Recency > 149.0].index, axis=0, inplace=True)

print('Shape antes da limpeza: ', df.shape)
print('Shape após a limpeza: ',df_clean.shape)
# Out:
# Shape antes da limpeza:  (2240, 29)
# Shape após a limpeza:  (2126, 29)

# %% [markdown]
# ## **Visualizando os Datasets Agora Limpos**
#
#  *Após a identificação dos outliers e a remoção dos mesmos, iremos agora plotar um _boxplot_ para visualizarmos a diferença e a clareza dos novos dados.*

# %% [markdown]
# ### **Boxplot da variável Clean** `Income`

# %%
fig, ax = plt.subplots(figsize=(15,3))
df_clean.Income.plot(kind='box', vert=False);
ax.set_title('Dataset Limpo - Income')
plt.show()
print("Tamanho original: {} colunas".format(df.shape[0]))
print("Tamanho atual: {} colunas".format(df_clean.shape[0]))
# Out:
# Tamanho original: 2240 colunas
# Tamanho atual: 2126 colunas

# %% [markdown]
# ### **Boxplot da variável Clean** `Year_Birth`

# %%
fig, ax = plt.subplots(figsize=(15,3))
df_clean.Year_Birth.plot(kind='box', vert=False);
ax.set_title('Dataset Limpo - Year_Birth')
plt.show()
print("Tamanho original: {} colunas".format(df.shape[0]))
print("Tamanho atual: {} colunas".format(df_clean.shape[0]))
# Out:
# Tamanho original: 2240 colunas
# Tamanho atual: 2126 colunas

# %% [markdown]
# ### **Boxplot da variável Clean** `Recency`

# %%
fig, ax = plt.subplots(figsize=(15,3))
df_clean.Recency.plot(kind='box', vert=False);
ax.set_title('Dataset Limpo - Recency')
plt.show()
print("Tamanho original: {} colunas".format(df.shape[0]))
print("Tamanho atual: {} colunas".format(df_clean.shape[0]))
# Out:
# Tamanho original: 2240 colunas
# Tamanho atual: 2126 colunas

# %% [markdown]
# ### **Boxplot da variável Clean** `NumDealsPurchases`

# %%
fig, ax = plt.subplots(figsize=(15,3))
df_clean.NumDealsPurchases.plot(kind='box', vert=False);
ax.set_title('Dataset Limpo - NumDealsPurchases')
plt.show()
print("Tamanho original: {} colunas".format(df.shape[0]))
print("Tamanho atual: {} colunas".format(df_clean.shape[0]))
# Out:
# Tamanho original: 2240 colunas
# Tamanho atual: 2126 colunas

# %% [markdown]
# ### **Boxplot da variável Clean** `NumWebPurchases`

# %%
fig, ax = plt.subplots(figsize=(15,3))
df_clean.NumWebPurchases.plot(kind='box', vert=False);
ax.set_title('Dataset Limpo - NumWebPurchases')
plt.show()
print("Tamanho original: {} colunas".format(df.shape[0]))
print("Tamanho atual: {} colunas".format(df_clean.shape[0]))
# Out:
# Tamanho original: 2240 colunas
# Tamanho atual: 2126 colunas

# %% [markdown]
# ### **Boxplot da variável Clean** `NumCatalogPurchases`

# %%
fig, ax = plt.subplots(figsize=(15,3))
df_clean.NumCatalogPurchases.plot(kind='box', vert=False);
ax.set_title('Dataset Limpo - NumCatalogPurchases')
plt.show()
print("Tamanho original: {} colunas".format(df.shape[0]))
print("Tamanho atual: {} colunas".format(df_clean.shape[0]))
# Out:
# Tamanho original: 2240 colunas
# Tamanho atual: 2126 colunas

# %% [markdown]
# ### **Boxplot da variável Clean** `NumStorePurchases`

# %%
fig, ax = plt.subplots(figsize=(15,3))
df_clean.NumStorePurchases.plot(kind='box', vert=False);
ax.set_title('Dataset Limpo - NumStorePurchases')
plt.show()
print("Tamanho original: {} colunas".format(df.shape[0]))
print("Tamanho atual: {} colunas".format(df_clean.shape[0]))
# Out:
# Tamanho original: 2240 colunas
# Tamanho atual: 2126 colunas

# %% [markdown]
#  Assim como o esperado, possuímos agora um gráfico bem mais claro mostrando bem o resultado da limpeza.
#
#  O boxplot mostra alguns dados como outliers, entretanto, esses estão sendo calculados em relação ao novo dataset, e nossa limpeza levou em consideração os quartis do dado original.
#
#  Para garantirmos que não estamos lidando com outliers que vão prejudicar nossa análise, vamos checar os histogramas novamente.

# %%
df_clean.hist(bins=12, figsize=(22,15), grid=False, color= '#ff4d00',ec = "w");

# %%
# Descrição dos Dados agora limpos
df_clean.describe().round(1)
# Out:
#             ID  Year_Birth    Income  ...  Z_CostContact  Z_Revenue  Response
# count   2126.0      2126.0    2105.0  ...         2126.0     2126.0    2126.0
# mean    5617.6      1968.9   51395.1  ...            3.0       11.0       0.1
# std     3254.2        12.0   20745.9  ...            0.0        0.0       0.4
# min        0.0      1893.0    3502.0  ...            3.0       11.0       0.0
# 25%     2855.0      1959.0   34600.0  ...            3.0       11.0       0.0
# 50%     5515.0      1970.0   50616.0  ...            3.0       11.0       0.0
# 75%     8456.5      1978.0   68462.0  ...            3.0       11.0       0.0
# max    11191.0      1996.0  105471.0  ...            3.0       11.0       1.0
#
# [8 rows x 26 columns]

# %% [markdown]
# ## **Correlação Entre as Variáveis**
#
#  *Correlação significa a existência de uma relação ou semelhança entre duas variáveis.*
#
#  *Para identificar as correlações existentes entre as variáveis de interesse, vamos:*
#
# * *Criar uma matriz de correlação*
# * *Gerar um *heatmap* a partir dessa matriz, usando a biblioteca `seaborn`*

# %%
corr = df_clean[['Income', 'Year_Birth', 'NumDealsPurchases','NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases']].corr()

display(corr)
# Out:
#                        Income  ...  NumStorePurchases
# Income               1.000000  ...           0.695509
# Year_Birth          -0.207791  ...          -0.131731
# NumDealsPurchases   -0.173566  ...           0.050243
# NumWebPurchases      0.540369  ...           0.560303
# NumCatalogPurchases  0.744506  ...           0.607947
# NumStorePurchases    0.695509  ...           1.000000
#
# [6 rows x 6 columns]

# %%
sns.heatmap(corr, cmap='RdBu', fmt='.2f', square=True, linecolor='white', annot=True);

# %% [markdown]
# ## **Média da Renda, Ano_Nascimento e compras por/pela:**
#   * **Ofertas;**
#   * **Web;**
#   * **Catálogo; e**
#   * **Loja.**

# %% [markdown]
# A seguir vamos obter a média  da Renda, Ano_Nascimento e compras por/pela: Ofertas,Web, Catálogo e Loja.

# %%
# Mostrando a média da Renda, Ano_Nascimento e compras por/pela: Ofertas,Web, Catálogo e Loja.
print('Média de Renda(Income): {:.0f}'.format(df_clean['Income'].mean()))
print('Média do Ano_Nascimento(Year_Birth): {:.0f}'.format(df_clean['Year_Birth'].mean()))
print('Média de Número  de compras por ofertas(NumDealsPurchases): {:.0f}'.format(df_clean['NumDealsPurchases'].mean()))
print('Média de Número  de compras pela web(NumWebPurchase): {:.0f}'.format(df_clean['NumWebPurchases'].mean()))
print('Média de Número  de compras por catálogo(NumCatalogPurchases): {:.0f}'.format(df_clean['NumCatalogPurchases'].mean()))
print('Média de Número  de compras pela loja (NumStorePurchases): {:.0f}'.format(df_clean['NumStorePurchases'].mean()))
# Out:
# Média de Renda(Income): 51395
# Média do Ano_Nascimento(Year_Birth): 1969
# Média de Número  de compras por ofertas(NumDealsPurchases): 2
# Média de Número  de compras pela web(NumWebPurchase): 4
# Média de Número  de compras por catálogo(NumCatalogPurchases): 3
# Média de Número  de compras pela loja (NumStorePurchases): 6

# %% [markdown]
# ## **Tabela descritiva de características categoriais**

# %%
# Lista de recursos categóricos::
feat_c = ["Education", "Marital_Status", "Kidhome", "Teenhome", "AcceptedCmp1", "AcceptedCmp2", "AcceptedCmp3", "AcceptedCmp4",
         "AcceptedCmp5", "Complain"]



# Recebe dataframe, lista de nomes de recursos categóricos (pode ser apenas 1), nome da variável targer,
# número de observações mínimas a serem levadas em consideração e limite de capacidade de discriminação e
# retorna uma tabela com estatísticas descritivas sobre esses recursos categóricos
def cat_feat_describe(df, fc, target, n, thresh):

    fl = []
    
    
    
    if (type(fc)==list):
    
        for feature in fc:
            fl.append(df.groupby([feature]).agg({target : ["count", "mean"]}))    

            fm = pd.concat(fl, keys=fc)

            fm = pd.DataFrame({"Número de observações" : fm.iloc[:,0], "Capacidade de Discriminação" : fm.iloc[:,1],
                                 "Mais de n observações" : fm.iloc[:,0]>n,
                                 "Maior capacidade de discriminação do que o Limiar" : fm.iloc[:,1]>thresh,
                                 "Ambos Verdadeiros" : ((fm.iloc[:,0]>n) & (fm.iloc[:,1]>thresh))})
    else:
        fm = (df.groupby(fc).agg({target : ["count", "mean"]}))
        
        fm = pd.DataFrame({"Número de observações" : fm.iloc[:,0], "Capacidade de Discriminação" : fm.iloc[:,1],
                                 "Mais de n observações" : fm.iloc[:,0]>n,
                                 "Maior capacidade de discriminação do que o Limiar" : fm.iloc[:,1]>thresh,
                                 "Ambos Verdadeiros" : ((fm.iloc[:,0]>n) & (fm.iloc[:,1]>thresh))})
        
    return fm






feat_sum = cat_feat_describe(df, feat_c, "Response", 40, 0.15)
feat_sum
# Out:
#                            Número de observações  ...  Ambos Verdadeiros
# Education      2n Cycle                      203  ...              False
#                Basic                          54  ...              False
#                Graduation                   1127  ...              False
#                Master                        370  ...               True
#                PhD                           486  ...               True
# Marital_Status Absurd                          2  ...              False
#                Alone                           3  ...              False
#                Divorced                      232  ...               True
#                Married                       864  ...              False
#                Single                        480  ...               True
#                Together                      580  ...              False
#                Widow                          77  ...               True
# ...

# %% [markdown]
# *Esses estados dessas classes apresentam um número decente de observações e uma capacidade de discriminação **superior a 15%**.*

# %%
feat_sum[feat_sum["Ambos Verdadeiros"]]
# Out:
#                          Número de observações  ...  Ambos Verdadeiros
# Education      Master                      370  ...               True
#                PhD                         486  ...               True
# Marital_Status Divorced                    232  ...               True
#                Single                      480  ...               True
#                Widow                        77  ...               True
# Kidhome        0                          1293  ...               True
# Teenhome       0                          1158  ...               True
# AcceptedCmp1   1                           144  ...               True
# AcceptedCmp3   1                           163  ...               True
# AcceptedCmp4   1                           167  ...               True
# AcceptedCmp5   1                           163  ...               True
#
# [11 rows x 5 columns]

# %% [markdown]
# ## **Estados de classes com poucas observações**
#
# *Podemos observar que existem três status da variável categorial Estado_Conjugal `Marital_Status` que guardam poucas observações embora não se enquadrem no estado civil comum que conhecemos. Devemos remover essas observações.*

# %%
feat_sum[-feat_sum["Mais de n observações"]]
# Out:
#                        Número de observações  ...  Ambos Verdadeiros
# Marital_Status Absurd                      2  ...              False
#                Alone                       3  ...              False
#                YOLO                        2  ...              False
# AcceptedCmp2   1                          30  ...              False
# Complain       1                          21  ...              False
#
# [5 rows x 5 columns]

# %% [markdown]
# ## **Visualização da capacidade de discriminação de características categóricas**

# %%
# Recebe um dataframe, lista de nomes de recursos categóricos (pode ser 1), o nome da variável de destino
# e o limite da capacidade de discriminação e gera todos os gráficos.
def cat_feat_plot(df, fc, target, thresh):

    sns.set_style("whitegrid")

    if (type(fc)==str):
        plot_df = cat_feat_describe(df, fc, target, 50, thresh).iloc[:,1]

        plot_df = plot_df.sort_values(ascending=False)

        ax = plot_df.plot.bar(color="red", title="{}% Linha liminar sobre a Capacidade de Discriminação".format(thresh*100), legend=False)
        ax.set_ylabel("Capacidade de Discriminação", size = 10)
        ax.axhline(y=thresh, color="black")
        ax.set_xticklabels(plot_df.index, rotation=50, size=10)


        plt.show()
        
        
        
    else:
        for feat in fc:
            plot_df = cat_feat_describe(df, feat, target, 50, thresh).iloc[:,1]

            plot_df = plot_df.sort_values(ascending=False)

            
            ax = plot_df.plot.bar(color="red", title="{}% Linha liminar sobre a Capacidade de Discriminação".format(thresh*100), legend=False)
            ax.set_ylabel("Capacidade de Discriminação", size = 10)
            ax.axhline(y=thresh, color="black")
            ax.set_xticklabels(plot_df.index, rotation=50, size=10)

            plt.show()
        
        
        
        
        
    
cat_feat_plot(df, feat_c, "Response", 0.15)

# %% [markdown]
# Nós podemos ver isso:
#
# * `Education` : Doutorado e Mestrado *estão acima do limite* de 15% de Capacidade de Discriminação.
# .
#
# * `MaritalStatus` : Somente Casados e Juntos estão *abaixo* do limiar.
#
# * `KidHome  &  TeenHome` : Apenas os clientes com *zero filhos* ou *adolescentes* mostram uma alta capacidade de discriminação.
#
#
# * `AcceptedCampaign` : Todas as 5 campanhas anteriores mostram que, como esperado, os clientes que aceitaram as campanhas apresentam capacidade de discriminação *acima* do limite.
#
# * `Complain` : Enquanto tanto quem faz quanto quem não registra apresentam *alta* capacidade de discriminação, *apenas os que fizeram queixa* apresentam capacidade de discriminação superior ao limiar.

# %% [markdown]
# ## **Análise de Variáveis ​​Numéricas**
#   * *Tratando Datas(Dt_Customer) e retornando em dias desde o registro*

# %%
# Obtém uma série de datas e seu formato como parâmetros e retorna uma série de dias desde aquela data até hoje.
def days_since(dates_series, date_format):

    n = len(dates_series)
    
    result = [0] * n

    for i in range(n):
        result[i] = (datetime.today()-datetime.strptime(dates_series[i], date_format)).days
    
    return result



df["Days_Customer"] = days_since(list(df.Dt_Customer), "%Y-%m-%d")

df= df.drop(columns="Dt_Customer")

df["Days_Customer"].head()
# Out:
# 0    3434
# 1    2884
# 2    3083
# 3    2910
# 4    2932
# Name: Days_Customer, dtype: int64

# %%
feat_n = list(df.columns)

feat_n = list(filter(lambda x: x not in feat_c, feat_n))

feat_n.remove("ID") #Removendo ID.
#Lista de Variáveis ​​Numéricas

df[feat_n].describe() # Descrevendo apenas Variáveis ​​Numéricas
# Out:
#         Year_Birth         Income  ...     Response  Days_Customer
# count  2240.000000    2216.000000  ...  2240.000000    2240.000000
# mean   1968.805804   52247.251354  ...     0.149107    3124.582143
# std      11.984069   25173.076661  ...     0.356274     202.122512
# min    1893.000000    1730.000000  ...     0.000000    2771.000000
# 25%    1959.000000   35303.000000  ...     0.000000    2951.750000
# 50%    1970.000000   51381.500000  ...     0.000000    3126.500000
# 75%    1977.000000   68522.000000  ...     0.000000    3300.000000
# max    1996.000000  666666.000000  ...     1.000000    3470.000000
#
# [8 rows x 18 columns]

# %% [markdown]
# ## **Variáveis ​​com variação zero (constantes)**

# %%
std = df[feat_n].describe().iloc[2,:]

const_lab = [std[std<0.05].index[0], std[std<0.05].index[1]]

std[std<0.05]
# Out:
# Z_CostContact    0.0
# Z_Revenue        0.0
# Name: std, dtype: float64

# %% [markdown]
# ## **Removendo variáveis ​​constantes**

# %%
df.drop(labels=const_lab, axis=1, inplace=True) # Agora data_ não contém variáveis ​​de variação zero.


feat_n = list(filter(lambda x: x not in const_lab, feat_n)) # Removendo os nomes das variáveis ​​sem variação
                                                        # da lista de recursos numéricos.

# %%
df.head()
# Out:
#      ID  Year_Birth   Education  ... Complain  Response  Days_Customer
# 0  5524        1957  Graduation  ...        0         1           3434
# 1  2174        1954  Graduation  ...        0         0           2884
# 2  4141        1965  Graduation  ...        0         0           3083
# 3  6182        1984  Graduation  ...        0         0           2910
# 4  5324        1981         PhD  ...        0         0           2932
#
# [5 rows x 27 columns]

# %% [markdown]
# ## **Inserindo Valores Omissos**
#
# * *Em vez de uma simples entrada média, empregamos o modelo de Regressão Linear do pacote sklearn para realizar uma previsão de quais seriam os valores ausentes em Renda considerando todas as outras variáveis ​​e usá-lo para inserir os valores ausentes.*

# %%
# Preparando todos os conjuntos de dados a serem usados ​​no Modelo de Regressão Linear
X = df
y = X["Income"]
y = y[-y.isna()]
X = X.drop(columns=["ID"])


X["Marital_Status"] = pd.Categorical(X["Marital_Status"])
X["Marital_Status"] = X["Marital_Status"].cat.codes

X["Education"] = pd.Categorical(X["Education"])
X["Education"] = X["Education"].cat.codes

x_pred = X[X.Income.isna()]
x_pred = x_pred.drop(columns="Income")

X = X[-X.Income.isna()]
X = X.drop(columns="Income")


# Modelo de Regressão Linear
reg = LinearRegression().fit(X, y)

# Previsões
y_pred = reg.predict(x_pred)

# Armazena as previsões nos valores ausentes
df.loc[df.Income.isna(), "Income"] = y_pred

# %% [markdown]
# ## **Valores ausentes**

# %%
# Recebe um dataframe e retorna uma tabela com contagem de valores ausentes, porcentagem e sinalizador superior a 3%.
def missing_rep(df):
    miss = df.isna().sum()
    miss = miss[miss>0]
    miss_p = miss/df.shape[0]
    miss_t = miss_p>0.03

    return pd.DataFrame({"Ausentes" : miss, "Proporção dos Ausentes" : miss_p, "Superior a 3%" : miss_t})



missing_rep(df)
# Out:
# Empty DataFrame
# Columns: [Ausentes, Proporção dos Ausentes, Superior a 3%]
# Index: []

# %% [markdown]
# ## **MUDANÇA**
# *O mesmo foi feito para Year_birth, pois eles eram inconsistentes.*

# %%
df[(2019 - df["Year_Birth"])>=90]
# Out:
#         ID  Year_Birth Education  ... Complain  Response  Days_Customer
# 192   7829        1900  2n Cycle  ...        1         0           3047
# 239  11004        1893  2n Cycle  ...        0         0           2814
# 339   1150        1899       PhD  ...        0         0           3047
#
# [3 rows x 27 columns]

# %%
# Preparando todos os conjuntos de dados a serem usados ​​no Modelo de Regressão Linear
X = df
y = X[(2019 - X["Year_Birth"])<90].Year_Birth
X = X.drop(columns=["ID"])

X["Marital_Status"] = pd.Categorical(X["Marital_Status"])
X["Marital_Status"] = X["Marital_Status"].cat.codes

X["Education"] = pd.Categorical(X["Education"])
X["Education"] = X["Education"].cat.codes

x_pred = X[(2019 - X["Year_Birth"])>=90]
x_pred = x_pred.drop(columns="Year_Birth")

X = X[(2019 - X["Year_Birth"])<90]
X = X.drop(columns="Year_Birth")





# Modelo de Regressão Linear
reg = LinearRegression().fit(X, y)

# Previsões
y_pred = reg.predict(x_pred)

# Armazena as previsões nos valores ausentes
df.loc[(2019 - df["Year_Birth"])>=90, "Year_Birth"] = y_pred.round()
df["Year_Birth"].astype('int')
# Out:
# 0       1957
# 1       1954
# 2       1965
# 3       1984
# 4       1981
#         ...
# 2235    1967
# 2236    1946
# 2237    1981
# 2238    1956
# 2239    1954
# Name: Year_Birth, Length: 2240, dtype: int64

# %%
#Deixando opção o download do conjunto de dados.
#df.to_excel(f'Conj_Dados_Regres_Linear.xlsx', index=False)

# %% [markdown]
#  ## **Matriz de Correlação entre Variáveis ​​Numéricas**
# *Empregamos aqui a matriz de correlação para encontrar variáveis ​​que apresentem alta correlação entre elas para que possamos eliminar uma ou juntá-las.*

# %%
# A função de "zoom" na matriz de correlação.
def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])]
#Pega um dataframe e retorna a matriz de correlação enquanto traça o gráfico da matriz de correlação usando tons de azul e vermelho.
#Calcula a matriz de correlação
def corr_matrix(df):
  corr = df.corr()
  cmap = sns.diverging_palette(5, 250, as_cmap=True)
  vis = corr.style.background_gradient(cmap, axis=1)\
  .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
  .set_caption("passe o nouse")\
  .set_precision(2)\
  .set_table_styles(magnify())
  return vis
  
  
  feat_n = feat_n.copy()
  feat_n.remove("Response")
  corr_matrix(df[feat_n])

# %%
# Função para encontrar o valor máximo em uma matriz de correlação e imprimir a linha e a coluna em que ela está localizada.
def max_matrix(matrix):

    aux = 0
    line = ""
    col = ""
    for l in matrix:
        for i in matrix:
            if ((matrix[l][i]<1) & (abs(matrix[l][i])>abs(aux))):
                aux = matrix[l][i]
                line = l
                col = i


    print("Max Value:", aux,
          "\nLine:", line,
          "\nColumn:", col)


    return aux


max_matrix(df[feat_n].corr())
# Out:
# Max Value: 0.723826590873882
# Line: MntMeatProducts
# Column: NumCatalogPurchases
# 0.723826590873882

# %% [markdown]
# *A maior correlação que temos é entre o número de **Produtos de Carne** (`MntMeatProducts`) adquiridos e o número de Compras do Catálogo (0,72).*

# %% [markdown]
# ## **Visualização de Variáveis ​​Numéricas**

# %%
# Pode dar de 1 a todos os recursos numéricos um feat_n.
# Pode fornecer um recurso categórico a ser usado (opcional)
def num_feat_plot(df, feat_nlist, target, feat_clist = None):
    
    if(target in feat_nlist):
        feat_nl = feat_nlist.copy()
        feat_nl.remove(target)
    
    if (feat_clist==None):
        
        if (type(feat_n)==str):
            
            sns.violinplot(data = df, y = feat_nl, x = target )
            plt.show()
            
            
        else:
            for feat in feat_n:
                sns.violinplot(data = df, y = feat, x = target)
                plt.show()
        
    else:
        if (type(feat_n)==str):
            
            sns.violinplot(data = df, y = feat_nl, x = feat_clist, hue = target)
            plt.show()
            
            
        else:
            for feat in feat_n:
                sns.violinplot(data = df, y = feat, x = feat_clist, hue = target)
                plt.show()
                
    return

num_feat_plot(df, feat_n, "Response")

# %% [markdown]
# *É claro que **Renda(Income)** possui muitos valores discrepantes altos, enquanto **Ano_Nascimento (Year_Birth)** possui valores discrepantes baixos. Algumas das variáveis ​​de **número de compras(number of purchases)** também apresentam altos valores discrepantes.*

# %%
num_feat_plot(df, feat_n, "Response", "Kidhome")

# %% [markdown]
# ## **Detecção de Outliers**
# * *Valores atípicos univariados:*
#   * *Cortes de Desvio Padrão:*
#
#   *Primeiro, usaremos o Desvio Padrão para encontrar outliers univariados em recursos numéricos. Toda observação acima de 3 desvios padrão de sua própria distribuição será considerada um outlier.*

# %%
# Função que recebe uma série e retorna uma lista de mesmo tamanho indicando com booleanos os outliers.
# 3 Desvios Padrão é o corte padrão.
def filter_by_std(series_, n_stdev=3.0, return_thresholds=False):
    mean_, stdev_ = series_.mean(), series_.std()
    cutoff = stdev_ * n_stdev
    lower_bound, upper_bound = mean_ - cutoff, mean_ + cutoff
    if return_thresholds:
        return lower_bound, upper_bound
    else:
        return [True if i < lower_bound or i > upper_bound else False for i in series_]

    
# Função que recebe uma série e retorna uma lista de mesmo tamanho indicando com boolean os outliers.
# 1.5 Intervalo Interquartil é o corte padrão.
def filter_by_iqr(series_, k=1.5, return_thresholds=False):
    q25, q75 = np.percentile(series_, 25), np.percentile(series_, 75)
    iqr = q75-q25
    
    cutoff = iqr*k
    lower_bound, upper_bound = q25-cutoff, q75+cutoff
    
    if return_thresholds:
        return lower_bound, upper_bound
    else:
        return [True if i < lower_bound or i > upper_bound else False for i in series_]

# %%
outliers = pd.DataFrame()

for feat in feat_n:
    outliers = outliers.append(df[filter_by_std(df[feat], n_stdev=3)])
    

outliers
# Out:
#          ID  Year_Birth   Education  ... Complain  Response  Days_Customer
# 164    8475      1973.0         PhD  ...        0         0           2891
# 617    1503      1976.0         PhD  ...        0         0           3162
# 655    5555      1975.0  Graduation  ...        0         0           2913
# 687    1501      1982.0         PhD  ...        0         0           3465
# 1300   5336      1971.0      Master  ...        0         0           3161
# ...     ...         ...         ...  ...      ...       ...            ...
# 1245   6862      1971.0  Graduation  ...        0         0           2813
# 1328   4246      1982.0      Master  ...        0         0           2970
# 1524  11110      1973.0  Graduation  ...        0         0           3213
# 1846   9931      1963.0         PhD  ...        0         0           2777
# 2214   9303      1976.0  Graduation  ...        0         0           3105
#
# [338 rows x 27 columns]

# %% [markdown]
# ## **Valores atípicos multivariados**
# * **Distância de Mahalanobis:**
#   * *A distância euclidiana é conhecida por não encontrar outliers ao lidar com dados multidimensionais. Então usamos a Distância de Mahalanobis, pois, como ela usa os autovalores das variáveis ​​em vez do eixo original, pode fazer algo semelhante a um dimensionamento de recursos.*
#   * *Basicamente calcula a distância de cada ponto ao centro de massa medido em desvios padrão através da matriz de covariância invertida.*
#   * *Com essas funções podemos encontrar as linhas que representam outliers multivariados. O único caminho a seguir é remover essas linhas, em vez de inserir os valores extremos, como quando estamos lidando com valores discrepantes univariados.*

# %%
#Função simples para verificar se a matriz é definida positiva (por exemplo, retornará False se a matriz contiver NaN).
def is_pos_def(A):
    if np.allclose(A, A.T):
        try:
            np.linalg.cholesky(A)
            return True
        except np.linalg.LinAlgError:
            return False
    else:
        return False 

    
    
    
    
    
# A função para calcular a distância de Mahalanobis. Retorna uma lista de distâncias.
def MahalanobisDist(data):
    covariance_matrix = np.cov(data, rowvar=False)
    if is_pos_def(covariance_matrix):
        inv_covariance_matrix = np.linalg.inv(covariance_matrix)
        if is_pos_def(inv_covariance_matrix):
            vars_mean = []
            for i in range(data.shape[0]):
                vars_mean.append(list(data.mean(axis=0)))
            diff = data - vars_mean
            md = []
            for i in range(len(diff)):
                md.append(np.sqrt(diff[i].dot(inv_covariance_matrix).dot(diff[i])))
            return md
        else:
            print("Erro: Inverso da Matriz de Covariância não é definido positivo!")
    else:
        print("Erro: Matriz de Covariância não é definida positiva!")

        
        
        
        
#Função para detectar outliers multivariados das Distâncias de Mahalanobis. Retorna uma matriz de índices dos valores discrepantes.    
def MD_detectOutliers(data, extreme=False):
    MD = MahalanobisDist(data)

    std = np.std(MD)
    k = 3. * std if extreme else 2. * std
    m = np.mean(MD)
    up_t = m + k
    low_t = m - k
    outliers = []
    for i in range(len(MD)):
        if (MD[i] >= up_t) or (MD[i] <= low_t):
            outliers.append(i)  # índice do outlier
    return np.array(outliers)

# %%
# Aqui estamos criando um dataframe auxiliar e inserindo NaN com a média para que possamos calcular as distâncias de Mahalanobis.
df_aux = df[feat_n]

df_aux = df_aux.apply(lambda x: x.fillna(x.mean()), axis=0)

# %%
#Executa a função
outliers_i = MD_detectOutliers(np.array(df_aux))
len(outliers_i)
# Out:
# 41

# %% [markdown]
# *Essas observações foram detectadas como outliers multivariados pelo método Mahalanobis Distance.*
#
# *Poderíamos simplesmente remover essas linhas do conjunto de dados, pois apenas 33 observações discrepantes foram detectadas.*
#
# *O que deveríamos fazer?*

# %%
# Linhas que foram detectadas como valores discrepantes multivariados:
dat = pd.DataFrame()
for i in outliers_i:
    dat = dat.append(df_aux.iloc[i,:])
    
dat
# Out:
#       Days_Customer         Income  ...  Response  Year_Birth
# 9            2879.0    5648.000000  ...       0.0      1950.0
# 21           3310.0    2447.000000  ...       0.0      1979.0
# 27           3265.0   82073.867295  ...       0.0      1986.0
# 67           2873.0   88194.000000  ...       1.0      1979.0
# 109          3340.0   89058.000000  ...       0.0      1960.0
# 164          2891.0  157243.000000  ...       0.0      1973.0
# 252          3221.0  102692.000000  ...       1.0      1974.0
# 287          3308.0   50898.000000  ...       0.0      1956.0
# 432          3293.0   67309.000000  ...       0.0      1967.0
# 528          3457.0   61839.000000  ...       0.0      1964.0
# 617          3162.0  162397.000000  ...       0.0      1976.0
# 644          3247.0   77632.000000  ...       1.0      1947.0
# 646          3295.0  105471.000000  ...       1.0      1970.0
# 655          2913.0  153924.000000  ...       0.0      1975.0
# ...

# %% [markdown]
# ## **Meios de Classificação do Valor dos Recursos**
# * *Precisamos de meios de raking o valor dos recursos para que possamos compará-los e verificar quais são os melhores para alimentá-los como entrada para o pipeline. Para fazer isso, queremos um algoritmo que possa nos dar alguma medida da capacidade de discriminação de todos os recursos em relação ao nosso recurso de resposta.*
#
# * *Depois de ter uma ferramenta para medir o valor, podemos ir em frente e criar novos recursos e compará-los com os que já temos.*
#
# #### **O Teste de Independência do χ2**
# * *O teste χ2 para independência, apesar de ter a hipótese nula de independência das variáveis, também pode medir o grau de associação entre duas variáveis, o que significa que podemos usá-lo para verificar qual característica é semelhante à nossa variável Resposta.*
#
# * *Para utilizar como entrada do teste um recurso numérico, foi empregada a estratégia de binning com 10 bins.*

# %%
# É dado como entrada um dataframe, uma lista de nomes de features contínuas, uma lista de nomes de features categóricas,
# o nome do recurso de destino e retorna um dataframe com a capacidade de discriminação de cada recurso e se
# seu valor p é menor que 0,05.
# 10 é o número padrão de bins e uniforme é a estratégia utilizada no binning de features contínuas.
def chisq_ranker(df, continuous_flist, categorical_flist, target, n_bins=10, binning_strategy="uniform"):
    chisq_dict = {}
    if  continuous_flist:
        bindisc = KBinsDiscretizer(n_bins=n_bins, encode='ordinal', 
                               strategy=binning_strategy)
        for feature in continuous_flist:            
            feature_bin = bindisc.fit_transform(df[feature].values[:, np.newaxis])
            feature_bin = pd.Series(feature_bin[:, 0], index=df.index)
            cont_tab = pd.crosstab(feature_bin, df[target], margins = False)
            chisq_dict[feature] = stats.chi2_contingency(cont_tab.values)[0:2] 
    if  categorical_flist:
        for feature in categorical_flist:  
            cont_tab = pd.crosstab(df[feature], df[target], margins = False)          
            chisq_dict[feature] = stats.chi2_contingency(cont_tab.values)[0:2]       
    
    df_chi = pd.DataFrame(chisq_dict, index=["Chi-Squared", "p-value"]).transpose()
    df_chi.sort_values("Chi-Squared", ascending=False, inplace=True)
    df_chi["valid"]=df_chi["p-value"]<=0.05
    
    
    return df_chi

# %% [markdown]
# ####*Agora podemos verificar a similaridade de cada característica com a Resposta`Response`, o que, por sua vez, significa que podemos verificar a capacidade de discriminação de nossas características.*
#
# ####*Na tabela podemos observar que, de acordo com o teste, o recurso `AcceptedCmp1` apresenta a maior capacidade de discriminação, seguido do recurso `AcceptedCmp5`.*

# %%
chisq_ranker(df, feat_n, feat_c, "Response")
# Out:
#                      Chi-Squared       p-value  valid
# Response             2232.125110  0.000000e+00   True
# AcceptedCmp5          235.467749  3.828045e-53   True
# AcceptedCmp1          190.241783  2.815498e-43   True
# MntWines              169.732680  7.014771e-32   True
# AcceptedCmp3          142.074884  9.364996e-33   True
# MntMeatProducts       137.985390  2.666965e-27   True
# NumCatalogPurchases   112.658836  1.123115e-22   True
# Recency               105.568964  1.170347e-18   True
# Days_Customer          97.837068  4.305265e-17   True
# Income                 87.217082  8.673384e-19   True
# AcceptedCmp4           68.312456  1.395368e-16   True
# NumWebPurchases        67.348217  1.428441e-12   True
# MntFruits              60.970552  8.712021e-10   True
# AcceptedCmp2           60.130297  8.878118e-15   True
# NumStorePurchases      58.516124  2.587168e-09   True
# Teenhome               58.338420  2.147697e-13   True
# ...

# %% [markdown]
# ## **Engenharia de recursos**
#
# * *Mesmo que o propósito de um DTA não seja exatamente medir o valor dos recursos, podemos usá-lo dessa maneira. Ao empregar o DecisionTreeClassifier do scikit-learn, podemos extrair as importâncias dos recursos da classe.*
#
# * *Agora, com um meio de comparar recursos de acordo com seu valor, podemos extrair novos recursos dos que já temos para buscar melhores recursos.*
#
# Vamos criar todos os novos recursos e compará-los e classificá-los posteriormente.

# %% [markdown]
# ## **Transformações de Poder**
#
#
# * *Aplicando as transformações Box-Cox em todas as características, podemos tentar encontrar as que melhor se ajustam a cada uma em termos de capacidade de discriminação.*
# * *Mas primeiro, precisamos executar o dimensionamento de recursos em variáveis ​​contínuas.*

# %%
# Dado um dataframe, uma lista numérica de nomes de recursos e um sufixo para o nome das novas variáveis ​​retorna um dataframe com o
# variáveis ​​originais e novas.
def MinMaxScaling(df, num_feat_list, suffix):

    data_scaler = df[num_feat_list]

    fscaler = MinMaxScaler()
    scaled_d = fscaler.fit_transform(data_scaler.values)

    colnames = [s + suffix for s in data_scaler.columns]

    return pd.concat([df, pd.DataFrame(scaled_d, index=data_scaler.index, columns=colnames)], axis=1)


data_t = MinMaxScaling(df, feat_n, "_t")
data_t.head()
# Out:
#      ID  Year_Birth  ... Response_t Days_Customer_t
# 0  5524      1957.0  ...        1.0        0.948498
# 1  2174      1954.0  ...        0.0        0.161660
# 2  4141      1965.0  ...        0.0        0.446352
# 3  6182      1984.0  ...        0.0        0.198856
# 4  5324      1981.0  ...        0.0        0.230329
#
# [5 rows x 43 columns]

# %%
# Recebe um dataframe que consiste apenas em recursos dimensionados e o destino e o nome do recurso de destino.
# Retorna tanto o dataframe com os recursos já transformados para a melhor transformação quanto um dicionário
# contendo o nome de cada recurso com seu melhor nome de transformação.

def power_transf(df, target_feat):

    #definir um conjunto de transformações
    trans_dict = {"x": lambda x: x, "log": np.log, "sqrt": np.sqrt, 
                  "exp": np.exp, "**1/4": lambda x: np.power(x, 0.25), 
                  "**2": lambda x: np.power(x, 2), "**4": lambda x: np.power(x, 4)}

    target = target_feat
    best_power_dict = {}
    for feature in df.columns[:-1]:
        max_test_value, max_trans, best_power_trans = 0, "", None
        for trans_key, trans_value in trans_dict.items():
            # aplica transformação
            feature_trans = trans_value(df[feature])
            if trans_key == "log":
                feature_trans.loc[np.isfinite(feature_trans)==False] = -50.

            # recurso bin
            bindisc = KBinsDiscretizer(n_bins=10, encode='ordinal', strategy="uniform")
            feature_bin = bindisc.fit_transform(feature_trans.values[:, np.newaxis])
            feature_bin = pd.Series(feature_bin[:, 0], index=df.index)

            # obter tabela de contingência
            df_ = pd.DataFrame(data={feature: feature_bin, target: df[target]})
            cont_tab = pd.crosstab(df_[feature], df_[target], margins = False)        

            # computa Qui-Quadrado
            chi_test_value = stats.chi2_contingency(cont_tab)[0]
            if chi_test_value > max_test_value:
                max_test_value, max_trans, best_power_trans = chi_test_value, trans_key, feature_trans      

        best_power_dict[feature] = (max_test_value, max_trans, best_power_trans)
        df[feature] = best_power_trans
        
    return df, best_power_dict

# %%
# Precisamos criar um dataframe contendo apenas os recursos dimensionados com o Response.
df_pt = data_t.iloc[:,-15:]
df_pt["Response"] = df["Response"]



data_pt, best_pt = power_transf(df_pt, "Response")
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
# ...

# %%
print("Melhor Transformação de Energia para cada recurso:")
for key in best_pt:
    print("\t->", key, best_pt[key][1])
# Out:
# Melhor Transformação de Energia para cada recurso:
# 	-> Income_t x
# 	-> Recency_t **1/4
# 	-> MntWines_t **2
# 	-> MntFruits_t sqrt
# 	-> MntMeatProducts_t **1/4
# 	-> MntFishProducts_t x
# 	-> MntSweetProducts_t sqrt
# 	-> MntGoldProds_t sqrt
# 	-> NumDealsPurchases_t sqrt
# 	-> NumWebPurchases_t sqrt
# 	-> NumCatalogPurchases_t sqrt
# 	-> NumStorePurchases_t sqrt
# 	-> NumWebVisitsMonth_t exp
# 	-> Response_t x
# 	-> Days_Customer_t **2

# %%
# Substituindo as antigas colunas de recursos dimensionados pelos recursos transformados de acordo com a melhor transformação
coln = data_pt.columns[:-1]
data_t.drop(columns=coln, inplace=True)
data_t[coln] = data_pt[coln]

data_ = data_t
data_.head()
# Out:
#      ID  Year_Birth  ... Response_t Days_Customer_t
# 0  5524      1957.0  ...        1.0        0.899648
# 1  2174      1954.0  ...        0.0        0.026134
# 2  4141      1965.0  ...        0.0        0.199230
# 3  6182      1984.0  ...        0.0        0.039544
# 4  5324      1981.0  ...        0.0        0.053051
#
# [5 rows x 43 columns]

# %%
data_.shape
# Out:
# (2240, 43)
